# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
import pandas as pd
import numpy as np
pd.options.display.max_rows = 500

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/loan_data_2007_2014.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(5)
# Out:
#         id  member_id  loan_amnt  ...  inq_fi  total_cu_tl inq_last_12m
# 0  1077501    1296599       5000  ...     NaN          NaN          NaN
# 1  1077430    1314167       2500  ...     NaN          NaN          NaN
# 2  1077175    1313524       2400  ...     NaN          NaN          NaN
# 3  1076863    1277178      10000  ...     NaN          NaN          NaN
# 4  1075358    1311748       3000  ...     NaN          NaN          NaN
#
# [5 rows x 74 columns]

# %%
class DataInfo:
    def __init__(self,df):
        self.df = df

    def info(self): 
        
        # Counting no of rows 
        print(f'\nTotal Rows : {self.df.shape[0]} \n' + '--'*10 )
      
        # Counting no of columns
        print(f'\nTotal Columns : {self.df.shape[1]} \n' + '--'*10)
        
        # Extracting column names
        column_name =  self.df.columns 
        print(f'\nColumn Names\n' + '--'*10 +  f'\n{column_name} \n \n')
        
        # Data type info
        print(f'Data Summary\n' + '--'*10)
        data_summary = self.df.info() 
        
        # Total null values by each categories
        null_values = self.df.isnull().sum() 
        print(f'\nNull values\n' + '--'*10 + f'\n{null_values} \n \n')

        # Descriptive statistics
        describe =  self.df.describe() 
        print(f'\nDescriptive Statistics\n' + '--'*10 +  f'\n{describe} \n \n')
        
        # Unique categories description
    def uniqueCategory(self):      
        
        # Number of Unique values in each column
        uniques_values = self.df.apply(lambda x : len(x.unique())) 
        print(f'Unique Values\n' + '--'*10 +  f'\n{uniques_values} \n \n')
        
        for i in self.df.columns: 
            if self.df[i].dtype == 'O':          # Columns having datatype object or categories in each column
                unique_category = set(self.df.loc[: , i])      # Unique categories in each columns
                
                if len(unique_category)>=100:
                    print(f'{i} -- {list(unique_category)[:50]}\n')
                    continue  #Taking only top 50 as more than 100 will messed up
                else:
                    print(f'\n{i} -- {unique_category}\n')

# %%
df_train_info = DataInfo(df)
df_train_info.info()
# Out:
# Total Rows : 466285
# --------------------
#
# Total Columns : 74
# --------------------
#
# Column Names
# --------------------
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose',
#        'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
# ...

# %%
#df_train_info.uniqueCategory()

# %%
# Feature Engineering

# %%
#Checking columns which has more than 80% data are null values
null_values_col = df.isnull().mean()
null_col = null_values_col[null_values_col>0.8].index
null_col
# Out:
# Index(['mths_since_last_record', 'annual_inc_joint', 'dti_joint',
#        'verification_status_joint', 'open_acc_6m', 'open_il_6m', 'open_il_12m',
#        'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util',
#        'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util', 'inq_fi',
#        'total_cu_tl', 'inq_last_12m'],
#       dtype='object')

# %%
len(null_col)
# Out:
# 18

# %%
df_train = df.copy()

# %%
df_train.drop(null_col , inplace= True ,axis=1)

# %%
df_train.head(3)
# Out:
#         id  member_id  loan_amnt  ...  tot_coll_amt  tot_cur_bal total_rev_hi_lim
# 0  1077501    1296599       5000  ...           NaN          NaN              NaN
# 1  1077430    1314167       2500  ...           NaN          NaN              NaN
# 2  1077175    1313524       2400  ...           NaN          NaN              NaN
#
# [3 rows x 56 columns]

# %%
df_train.shape[1]
# Out:
# 56

# %%
df_train.drop(columns = ['id', 'member_id', 'sub_grade', 'emp_title', 'url', 'desc', 'title', 'zip_code', 'next_pymnt_d',
                          'recoveries', 'collection_recovery_fee', 'total_rec_prncp', 'total_rec_late_fee'], inplace = True)

# %%
df_train.head(2)
# Out:
#    loan_amnt  funded_amnt  ...  tot_cur_bal total_rev_hi_lim
# 0       5000         5000  ...          NaN              NaN
# 1       2500         2500  ...          NaN              NaN
#
# [2 rows x 43 columns]

# %%
# explore the unique values in loan_status column
df_train['loan_status'].value_counts(normalize = True)
# Out:
# Current                                                0.480878
# Fully Paid                                             0.396193
# Charged Off                                            0.091092
# Late (31-120 days)                                     0.014798
# In Grace Period                                        0.006747
# Does not meet the credit policy. Status:Fully Paid     0.004263
# Late (16-30 days)                                      0.002612
# Default                                                0.001784
# Does not meet the credit policy. Status:Charged Off    0.001632
# Name: loan_status, dtype: float64

# %%
set(df_train['loan_status'])
# Out:
# {'Charged Off',
#  'Current',
#  'Default',
#  'Does not meet the credit policy. Status:Charged Off',
#  'Does not meet the credit policy. Status:Fully Paid',
#  'Fully Paid',
#  'In Grace Period',
#  'Late (16-30 days)',
#  'Late (31-120 days)'}

# %%
bad_loans = [
    'Charged Off',
    'Default',
    'Does not meet the credit policy. Status:Charged Off',
    'In Grace Period',
    'Late (31-120 days)']

# %%
df_train['loan_status_'] = np.where(df_train.loc[:, 'loan_status'].isin(bad_loans), 0, 1)

# %%
df_train.drop('loan_status',inplace = True,axis=1)

# %%
df_train.head()
# Out:
#    loan_amnt  funded_amnt  ...  total_rev_hi_lim loan_status_
# 0       5000         5000  ...               NaN            1
# 1       2500         2500  ...               NaN            0
# 2       2400         2400  ...               NaN            1
# 3      10000        10000  ...               NaN            1
# 4       3000         3000  ...               NaN            1
#
# [5 rows x 43 columns]

# %%
set(df_train['emp_length'])
# Out:
# {'1 year',
#  '10+ years',
#  '2 years',
#  '3 years',
#  '4 years',
#  '5 years',
#  '6 years',
#  '7 years',
#  '8 years',
#  '9 years',
#  '< 1 year',
#  nan}

# %%
null_val_rows = df_train[df_train['emp_length'].isnull()]
null_val_rows.head()
# Out:
#      loan_amnt  funded_amnt  ...  total_rev_hi_lim loan_status_
# 168       2500         2500  ...               NaN            0
# 323      18000        18000  ...               NaN            1
# 394       4000         4000  ...               NaN            1
# 422       1000         1000  ...               NaN            0
# 439       8250         8250  ...               NaN            1
#
# [5 rows x 43 columns]

# %%
employement_mapping = {'1 year':1,
 '10+ years':10,
 '2 years':2,
 '3 years':3,
 '4 years':4,
 '5 years':5,
 '6 years':6,
 '7 years':7,
 '8 years':8,
 '9 years':9,
 '< 1 year':0
}

# %%
df_train.loc[:,'emp_length'] = df_train['emp_length'].map(employement_mapping)

# %%
'''from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)

missing_impute = df_train['emp_length'].values.reshape(-1,1)

df_filled = imputer.fit_transform(missing_impute)

df_filled '''

# %%
df_train.head()
# Out:
#    loan_amnt  funded_amnt  ...  total_rev_hi_lim loan_status_
# 0       5000         5000  ...               NaN            1
# 1       2500         2500  ...               NaN            0
# 2       2400         2400  ...               NaN            1
# 3      10000        10000  ...               NaN            1
# 4       3000         3000  ...               NaN            1
#
# [5 rows x 43 columns]

# %%
set(df_train['grade'])
# Out:
# {'A', 'B', 'C', 'D', 'E', 'F', 'G'}

# %%
set(df_train['home_ownership'])
# Out:
# {'ANY', 'MORTGAGE', 'NONE', 'OTHER', 'OWN', 'RENT'}
